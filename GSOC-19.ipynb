# %%
import requests,bs4

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
browser = webdriver.PhantomJS('/home/aman-py/phantomjs-2.1.1-linux-x86_64/bin/phantomjs')
# Out:
# /usr/local/lib/python3.5/dist-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '

# %%
browser.get('https://summerofcode.withgoogle.com/organizations/?sp-page=5')

# %%
html = browser.page_source

# %%
soup = bs4.BeautifulSoup(html,'lxml')

# %%
md_cards=soup.find_all('md-card',{'class':'organization-card _md md-soc-theme flex'})

# %%
data_ids = []
for i in md_cards:
    data_ids.append(i['data-id'])

# %%
len(data_ids)
# Out:
# 206

# %%
browse = webdriver.PhantomJS('/home/aman-py/phantomjs-2.1.1-linux-x86_64/bin/phantomjs')
browse.get('https://summerofcode.withgoogle.com/organizations/#5938771267158016/')
source = browse.page_source
sp = bs4.BeautifulSoup(source,'lxml')
# Out:
# /usr/local/lib/python3.5/dist-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '

# %%
brows = webdriver.PhantomJS('/home/aman-py/phantomjs-2.1.1-linux-x86_64/bin/phantomjs')
brows.get('https://summerofcode.withgoogle.com/organizations/5938771267158016/')
sourc = brows.page_source
spc = bs4.BeautifulSoup(sourc,'lxml')
# Out:
# /usr/local/lib/python3.5/dist-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '

# %%
org_meta_data=spc.find('div',{'class':'banner__text fixed-width'})
org_name = org_meta_data.contents[1].text.strip()
org_link=org_meta_data.contents[3].text.strip()
print(org_name)
print(org_link)
# Out:
# 52°North Initiative for Geospatial Open Source Software GmbH
# https://52north.org/

# %%
project_stack = spc.find('div',{'class':'org__meta'}).contents
idealistln=project_stack[3]
tech_stack=project_stack[6].find_all('li')

# %%
topic_stack=project_stack[13].find_all('li')

# %%
project_stack[16].find('a')['href']
# Out:
# 'https://wiki.52north.org/Projects/GSoC#Contact'

# %%
idea_list_link=idealistln.find('a')['href']
tech_ = []
topic =[]
for i in tech_stack:
    tech_.append(i.text)
for j in topic_stack:
    topic.append(j.text)
print(tech_)
print(topic)
print(idea_list_link)
# Out:
# ['javascript', 'android', 'web', ' java']
# ['Science and Medicine', 'ogc', 'web processing', 'sensorweb', 'floating car data', 'earth observation']
# https://wiki.52north.org/Projects/GSoC2019ProjectIdeas

# %%
brow1 = webdriver.PhantomJS('/home/aman-py/phantomjs-2.1.1-linux-x86_64/bin/phantomjs')
brow1.get('https://summerofcode.withgoogle.com/organizations/#6118953540124672/')
sour1 = brow1.page_source
sp1 = bs4.BeautifulSoup(sour1,'lxml')
brows1 = webdriver.PhantomJS('/home/aman-py/phantomjs-2.1.1-linux-x86_64/bin/phantomjs')
brows1.get('https://summerofcode.withgoogle.com/organizations/6118953540124672/')
sourc1 = brows1.page_source
spc1 = bs4.BeautifulSoup(sourc1,'lxml')
# Out:
# /usr/local/lib/python3.5/dist-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '

# %%
org_meta_data1=spc1.find('div',{'class':'banner__text fixed-width'})
org_name1 = org_meta_data1.contents[1].text.strip()
org_link1=org_meta_data1.contents[3].text.strip()
print(org_name1)
print(org_link1)
# Out:
# AboutCode.org
# https://aboutcode.org

# %%
project_stack1 = spc1.find('div',{'class':'org__meta'}).contents
idealistln1=project_stack1[3]
tech_stack1=project_stack1[6].find_all('li')
topic_stack1=project_stack1[13].find_all('li')
idea_list_link1=idealistln1.find('a')['href']
chat_link1=project_stack[16].find('a')['href']
tech_1 = []
topic1 =[]
for i in tech_stack1:
    tech_1.append(i.text)
for j in topic_stack1:
    topic1.append(j.text)
print(tech_1)
print(topic1)
print(idea_list_link1)
print(chat_link1)
# Out:
# ['python', ' javascript', 'nlp', 'automaton', 'search']
# ['Other', 'license-scan', 'oss licensing', 'package managers', 'copyright', 'license compliance']
# https://github.com/nexB/aboutcode/wiki/GSOC-2019
# https://wiki.52north.org/Projects/GSoC#Contact

# %%
title = []
meta_data = []
for i in data_ids[2:]:
    brow1 = webdriver.PhantomJS('/home/aman-py/phantomjs-2.1.1-linux-x86_64/bin/phantomjs')
    brow1.get('https://summerofcode.withgoogle.com/organizations/#'+i)
    sour1 = brow1.page_source
    sp1 = bs4.BeautifulSoup(sour1,'lxml')
    brows1 = webdriver.PhantomJS('/home/aman-py/phantomjs-2.1.1-linux-x86_64/bin/phantomjs')
    brows1.get('https://summerofcode.withgoogle.com/organizations/'+i)
    sourc1 = brows1.page_source
    spc1 = bs4.BeautifulSoup(sourc1,'lxml')
    meta_data.append(spc1.find('div',{'class':'org__meta'}))
    title.append(spc1.find('div',{'class':'banner__text fixed-width'}))
# Out:
# /usr/local/lib/python3.5/dist-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
d={'org_name':[],'category':[],'tech':[],'topics':[]}
i = 0
for x in data_ids[153:]:
    flag = True
    while flag:
        try:
            browse = webdriver.PhantomJS('/home/aman-py/phantomjs-2.1.1-linux-x86_64/bin/phantomjs')
            browse.get('https://summerofcode.withgoogle.com/organizations/?sp-page=5#'+x)
            source = browse.page_source
            soup = bs4.BeautifulSoup(source,'lxml')
            org_name=soup.find('h2',{'class':'organization-card__title md-display-2'}).text
            print(i)
            print(org_name)
            zp=soup.find_all('li',{'class':'organization__tag organization__tag--technology'})
            tech = [i.text for i in zp]
            print(tech)
            category = soup.find('li',{'class':'organization__tag organization__tag--category'}).text
            print(category)
            tp=soup.find_all('li',{'class':'organization__tag organization__tag--topic'})
            topics = [j.text for j in tp]
            print(topics)
            d['org_name'].append(org_name)
            d['category'].append(category)
            d['tech'].append(tech)
            d['topics'].append(topics)
            i+=1
            flag = False
        except AttributeError:
            print('Attribute Error Occured')
        
    
    #print(x)
    #print(org_name)
    #print(tech)
    #print(category)
    #print(topics)
# Out:
# /usr/local/lib/python3.5/dist-packages/selenium/webdriver/phantomjs/webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# 0
# Ruby
# ['ruby', 'c']
# Programming Languages and Development Tools
# ['programming languages', 'developer tools', 'web servers']
# 1
# Ruby Science Foundation
# ['ruby', 'c/c++', 'cuda', 'ai', 'machine learning']
# Science and Medicine
# ['scientific computing', ' scientific visualization', 'data-science', 'hpc', 'linear algebra']
# 2
# SageMath
# ['python', 'cython']
# Science and Medicine
# ['mathematics', 'education', 'research', 'math']
# 3
# Salesforce
# ['scala', ' apache spark', 'javascript', ' nodejs', 'react']
# Cloud
# ['machine learning', 'natural language processing', ' web applications', 'user interface', 'cli']
# 4
# Samba
# ['c', 'smb']
# Data and Databases
# ...

# %%
import pandas as pd
data = pd.DataFrame(d)

# %%
data
# Out:
#                                        category  \
# 0   Programming Languages and Development Tools
# 1                          Science and Medicine
# 2                          Science and Medicine
# 3                                         Cloud
# 4                            Data and Databases
# 5                                      Security
# 6                                         Other
# 7                          Science and Medicine
# 8   Programming Languages and Development Tools
# 9                            Data and Databases
# 10  Programming Languages and Development Tools
# 11                            Operating Systems
# 12                                        Other
# 13                        End User Applications
# 14  Programming Languages and Development Tools
# 15  Programming Languages and Development Tools
# 16                         Science and Medicine
# 17   Graphics / Video / Audio / Virtual Reality
# ...

# %%
data.to_csv('GSOC13.csv')

# %%
data1 = pd.read_csv('GSOC.csv')
data2 = pd.read_csv('GSOC1.csv')
data3 = pd.read_csv('GSOC2.csv')

# %%
df_row_merged = pd.concat([data1, data2,data3], ignore_index=True)

# %%
data4 = pd.read_csv('GSOC3.csv')
data5 = pd.read_csv('GSOC4.csv')
data6 = pd.read_csv('GSOC5.csv')

# %%
df_row_merged = pd.concat([df_row_merged,data4,data5,data6],ignore_index=True)

# %%
data7 = pd.read_csv('GSOC6.csv')
data8 = pd.read_csv('GSOC7.csv')

# %%
data9 = pd.read_csv('GSOC8.csv')
data10 = pd.read_csv('GSOC9.csv')

# %%
data11 = pd.read_csv('GSOC10.csv')
data12 = pd.read_csv('GSOC11.csv')
data13 = pd.read_csv('GSOC12.csv')

# %%
df_row_merged = pd.concat([df_row_merged,data],ignore_index=True)

# %%
df_row_merged.to_csv('GSOC.csv')

# %%
df=df_row_merged.drop('Unnamed: 0',axis=1)

# %%
df.head()
# Out:
#                                       category  \
# 0                         Science and Medicine
# 1                                        Other
# 2                         Science and Medicine
# 3  Programming Languages and Development Tools
# 4                        End User Applications
#
#                                             org_name  \
# 0  52°North Initiative for Geospatial Open Source...
# 1                                      AboutCode.org
# 2                              AerospaceResearch.net
# 3                                           aimacode
# 4                                              Amahi
#
#                                                 tech  \
# 0          ['javascript', 'android', 'web', ' java']
# 1  ['python', ' javascript', 'nlp', 'automaton', ...
# 2      ['python', ' c/c++', 'vhdl', 'boinc', 'java']
# 3  ['python', 'python 3', ' java', ' javascript',...
# 4  ['golang', 'ruby on rails', ' android', 'ios',...
#
# ...

# %%
soup.find('h2',{'class':'organization-card__title md-display-2'})
# Out:
# '52°North Initiative for Geospatial Open Source Software GmbH'

# %%
soup.find_all('li',{'class':'organization__tag organization__tag--technology'})
# Out:
# [<li class="organization__tag organization__tag--technology" ng-repeat="tag in orgDetail.organization.technology_tags" style="">javascript</li>,
#  <li class="organization__tag organization__tag--technology" ng-repeat="tag in orgDetail.organization.technology_tags">android</li>,
#  <li class="organization__tag organization__tag--technology" ng-repeat="tag in orgDetail.organization.technology_tags">web</li>,
#  <li class="organization__tag organization__tag--technology" ng-repeat="tag in orgDetail.organization.technology_tags"> java</li>]

# %%
soup.find_all('li',{'class':'organization__tag organization__tag--category'})
# Out:
# [<li class="organization__tag organization__tag--category" ng-if="orgDetail.organization.category" style="">Science and Medicine</li>]

# %%
toipcs=soup.find_all('li',{'class':'organization__tag organization__tag--topic'})

# %%
import re
reg = re.compile(r'<li class="organization__tag organization__tag--technology" ng-repeat="tag in orgDetail.organization.technology_tags" style="">(.*)</li>')

# %%
re.search(reg,source)
# Out:
# <_sre.SRE_Match object; span=(564857, 565404), match='<li class="organization__tag organization__tag--t>

# %%
brsr = webdriver.Chrome('/home/aman-py/LearnCodeOnline_Python/chromedriver')
brsr.get('https://summerofcode.withgoogle.com/organizations/?sp-page=5')
elm = brsr.find_element_by_tag_name('html')
i = 0
while i<5000000:
    elm.send_keys(Keys.END)
    i+=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-40228dfbc654> in <module>()
#       4 i = 0
#       5 while i<5000000:
# ----> 6     elm.send_keys(Keys.END)
#       7     i+=1
#
# ...
